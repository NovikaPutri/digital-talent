# %%
print ("BIG DATA (WORD COUNT) - KELAS C")
print ("NOVIKA PUTRI")
print () 

paragraf = "Barcelona berhasil merebut posisi puncak klasemen La Liga Spanyol seusai menang 4-2 atas Sevilla pada pertandingan pekan kesembilan di Stadion Camp Nou, Sabtu (20/10/2018) atau Minggu dini hari WIB. Barcelona membuka keunggulan pada menit ke-2 melalui gol yang dicetak oleh Philippe Coutinho. Lionel Messi menggandakan keunggulan Barcelona, 10 menit berselang.  Namun, nahas bagi Barcelona, karena Messi harus ditarik keluar pada menit ke-26 setelah mengalami cedera. Tanpa Messi, skor 2-0 bertahan hingga babak pertama berakhir."
print(paragraf)

#datacleansing
paragraf = paragraf.replace("-", " ")
paragraf = paragraf.replace("/", " ")
paragraf = paragraf.replace(",", " ")
paragraf = paragraf.replace("("," ")
paragraf = paragraf.replace(")", " ")
paragraf = paragraf.split()
words={}
print()
print("Jadi banyaknya kemunculan masing-masing kata adalah sebagai berikut :")

for wrd in paragraf:
    if wrd in words:
        words[wrd]+=1
    else:
        words[wrd]=1
for w,k in words.items():
    print("~",w,"ada",k,"kemunculan")
# Out:
# BIG DATA (WORD COUNT) - KELAS C
# NOVIKA PUTRI
#
# Barcelona berhasil merebut posisi puncak klasemen La Liga Spanyol seusai menang 4-2 atas Sevilla pada pertandingan pekan kesembilan di Stadion Camp Nou, Sabtu (20/10/2018) atau Minggu dini hari WIB. Barcelona membuka keunggulan pada menit ke-2 melalui gol yang dicetak oleh Philippe Coutinho. Lionel Messi menggandakan keunggulan Barcelona, 10 menit berselang.  Namun, nahas bagi Barcelona, karena Messi harus ditarik keluar pada menit ke-26 setelah mengalami cedera. Tanpa Messi, skor 2-0 bertahan hingga babak pertama berakhir.
#
# Jadi banyaknya kemunculan masing-masing kata adalah sebagai berikut :
# ~ Barcelona ada 4 kemunculan
# ~ berhasil ada 1 kemunculan
# ~ merebut ada 1 kemunculan
# ~ posisi ada 1 kemunculan
# ~ puncak ada 1 kemunculan
# ~ klasemen ada 1 kemunculan
# ~ La ada 1 kemunculan
# ~ Liga ada 1 kemunculan
# ~ Spanyol ada 1 kemunculan
# ~ seusai ada 1 kemunculan
# ~ menang ada 1 kemunculan
# ~ 4 ada 1 kemunculan
# ~ 2 ada 3 kemunculan
# ~ atas ada 1 kemunculan
# ~ Sevilla ada 1 kemunculan
# ~ pada ada 3 kemunculan
# ~ pertandingan ada 1 kemunculan
# ~ pekan ada 1 kemunculan
# ~ kesembilan ada 1 kemunculan
# ~ di ada 1 kemunculan
# ~ Stadion ada 1 kemunculan
# ~ Camp ada 1 kemunculan
# ~ Nou ada 1 kemunculan
# ~ Sabtu ada 1 kemunculan
# ~ 20 ada 1 kemunculan
# ~ 10 ada 2 kemunculan
# ~ 2018 ada 1 kemunculan
# ~ atau ada 1 kemunculan
# ~ Minggu ada 1 kemunculan
# ~ dini ada 1 kemunculan
# ~ hari ada 1 kemunculan
# ~ WIB. ada 1 kemunculan
# ~ membuka ada 1 kemunculan
# ~ keunggulan ada 2 kemunculan
# ~ menit ada 3 kemunculan
# ~ ke ada 2 kemunculan
# ~ melalui ada 1 kemunculan
# ~ gol ada 1 kemunculan
# ~ yang ada 1 kemunculan
# ~ dicetak ada 1 kemunculan
# ~ oleh ada 1 kemunculan
# ~ Philippe ada 1 kemunculan
# ~ Coutinho. ada 1 kemunculan
# ~ Lionel ada 1 kemunculan
# ~ Messi ada 3 kemunculan
# ~ menggandakan ada 1 kemunculan
# ~ berselang. ada 1 kemunculan
# ~ Namun ada 1 kemunculan
# ~ nahas ada 1 kemunculan
# ~ bagi ada 1 kemunculan
# ~ karena ada 1 kemunculan
# ~ harus ada 1 kemunculan
# ~ ditarik ada 1 kemunculan
# ~ keluar ada 1 kemunculan
# ~ 26 ada 1 kemunculan
# ~ setelah ada 1 kemunculan
# ~ mengalami ada 1 kemunculan
# ~ cedera. ada 1 kemunculan
# ~ Tanpa ada 1 kemunculan
# ~ skor ada 1 kemunculan
# ~ 0 ada 1 kemunculan
# ~ bertahan ada 1 kemunculan
# ~ hingga ada 1 kemunculan
# ~ babak ada 1 kemunculan
# ~ pertama ada 1 kemunculan
# ~ berakhir. ada 1 kemunculan
